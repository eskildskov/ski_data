# %%
import json
from pydantic import BaseModel, ValidationError, Field, validator
from typing import Optional, Any
# from geojson_length import calculate_distance, Unit
import requests

# %%
def string_to_bool_or_none(val:str):
    if not isinstance(val, str):
      return val

    if val == '':
      return None

    lowered_val = val.lower()

    if lowered_val == "false" or lowered_val == "usann":
        return False
    
    if lowered_val == "true" or lowered_val == "sann":
        return True

    return val

# %%
r = requests.get("http://localhost:8055/items/routes?limit=-1&fields=*.*")
routes = r.json()['data']
routes
# Out:
# [{'id': 0,
#   'date_created': '2023-04-15T06:40:21.723Z',
#   'date_updated': None,
#   'aspect': ['S', 'Ø'],
#   'name': 'Ytstenesdalen',
#   'dangers': 'Steinsprang, elvegjøl, elveleie 100-530',
#   'comment': 'Mellom 100-180 følger ruta en gammel vei/sti som går under store klippepartier. Det er sjelden mye snø i denne sida opp til 180.',
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.399579, 62.317338],
#      [6.399515, 62.317527],
#      [6.398721, 62.317478],
#      [6.398849, 62.317278],
#      [6.399193, 62.317079],
#      [6.399193, 62.31662],
#      [6.397347, 62.31671],
#      [6.39636, 62.316102],
#      [6.396232, 62.315703],
#      [6.396317, 62.315225],
#      [6.396532, 62.314577],
#      [6.396532, 62.314008],
#      [6.396682, 62.31347],
#      [6.396832, 62.313061],
#      [6.39709, 62.312313],
#      [6.397079, 62.312029],
#      [6.397294, 62.311855],
#      [6.397401, 62.31166],
#      [6.397208, 62.311471],
#      [6.397326, 62.311281],
#      [6.397433, 62.311132],
#      [6.397315, 62.311032],
#      [6.397455, 62.310928],
#      [6.397412, 62.310698],
#      [6.397305, 62.310299],
#      [6.397246, 62.309945],
#      [6.397117, 62.309776],
#      [6.396993, 62.309584],
#      [6.396806, 62.309357],
#      [6.396688, 62.30921],
#      [6.396489, 62.309075],
#      [6.396226, 62.308933],
#      [6.39598, 62.308784],
#      [6.395749, 62.308642],
#      [6.395609, 62.308502],
#      [6.395658, 62.308318],
#      [6.395336, 62.308153],
#      [6.394799, 62.308048],
#      [6.394359, 62.307981],
#      [6.394172, 62.307899],
#      [6.393351, 62.307669],
#      [6.3915, 62.307206],
#      [6.389993, 62.306782],
#      [6.389129, 62.306473],
#      [6.388518, 62.306288],
#      [6.387906, 62.306156],
#      [6.387396, 62.306007],
#      [6.386415, 62.305924],
#      [6.385578, 62.305979],
#      [6.385143, 62.306044],
#      [6.384543, 62.306086],
#      [6.383266, 62.306236],
#      [6.38303, 62.306321],
#      [6.382381, 62.306286],
#      [6.380771, 62.306385],
#      [6.380042, 62.30647],
#      [6.379012, 62.30643],
#      [6.376104, 62.30641],
#      [6.372156, 62.306251],
#      [6.369238, 62.30656],
#      [6.367435, 62.30673],
#      [6.367178, 62.307049],
#      [6.367114, 62.307368],
#      [6.366448, 62.308066],
#      [6.366019, 62.308365],
#      [6.365826, 62.308873],
#      [6.365504, 62.309203],
#      [6.364517, 62.309502],
#      [6.358305, 62.310888],
#      [6.355172, 62.312084],
#      [6.353037, 62.313126],
#      [6.350387, 62.312981],
#      [6.349411, 62.312722],
#      [6.348896, 62.312613],
#      [6.348553, 62.312608],
#      [6.348113, 62.312618],
#      [6.34793, 62.312418],
#      [6.347791, 62.312254],
#      [6.347812, 62.312009],
#      [6.347265, 62.311964],
#      [6.34674, 62.312179],
#      [6.346074, 62.312538],
#      [6.345377, 62.312603],
#      [6.344894, 62.312632],
#      [6.343655, 62.313333],
#      [6.342604, 62.314061],
#      [6.342094, 62.314098]]}},
#   'max_start_altitude': 7,
#   'avalanche_start_zones': [['100-180', '30-38'],
#    ['450-520', '30-34'],
#    ['705-890', '30-45'],
#    ['1110-1222', '32-39'],
#    ['1234-1271', '30'],
#    ['1280-1404', '33-37']],
#   'max_steepness': 45,
#   'parking_location': 'Parkeringslomme rett S for skredtunnel',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': 'Stegjern og isøks',
#   'elevation': 1407,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 42,
#    'name': 'Randers topp',
#    'altitude': 1414,
#    'area': 'Kolåshalvøya',
#    'routes': [0, 5]}},
#  {'id': 1,
#   'date_created': '2023-04-15T06:40:21.730Z',
#   'date_updated': None,
#   'aspect': ['S', 'SØ'],
#   'name': 'Normalveien',
#   'dangers': None,
#   'comment': '20 m med 50 grader. Ski på sekk. Eksponert topprygg. ',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.704514, 62.226331],
#      [6.701757, 62.226341],
#      [6.701016, 62.226156],
#      [6.700641, 62.226431],
#      [6.700501, 62.226686],
#      [6.700287, 62.226851],
#      [6.700201, 62.227111],
#      [6.699986, 62.227316],
#      [6.700062, 62.227396]]}},
#   'max_start_altitude': 360,
#   'avalanche_start_zones': [['1000-1160', '31-35'], ['1240-1310', '32-34']],
#   'max_steepness': 50,
#   'parking_location': 'Langesæterdalen',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': 'Stegjern og isøks',
#   'elevation': 1190,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 36,
#    'name': 'Lille Brekketind',
#    'altitude': 1550,
#    'area': 'Rånahalvøya',
#    'routes': [1, 20]}},
#  {'id': 2,
#   'date_created': '2023-04-15T06:40:21.734Z',
#   'date_updated': None,
#   'aspect': ['S', 'SØ'],
#   'name': 'Normalveien',
#   'dangers': 'Søkkformasjoner i nedre del/midten av Brekketindbreen',
#   'comment': 'Breen har hatt stor avsmelting de siste årene, og fronten blir brattere og brattere. Bregleppe i renna fra breen og opp på ryggen. ',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.719685, 62.211454],
#      [6.713805, 62.214495],
#      [6.711402, 62.214475],
#      [6.711059, 62.218436],
#      [6.711059, 62.219056],
#      [6.709471, 62.220096],
#      [6.708527, 62.221116],
#      [6.708012, 62.221616],
#      [6.704321, 62.222916],
#      [6.703634, 62.224136],
#      [6.703978, 62.224956],
#      [6.704321, 62.226056],
#      [6.704235, 62.227366],
#      [6.704171, 62.227946],
#      [6.704074, 62.228326],
#      [6.70401, 62.228516],
#      [6.703323, 62.229121],
#      [6.703495, 62.229251],
#      [6.703688, 62.229216],
#      [6.704042, 62.229291]]}},
#   'max_start_altitude': 360,
#   'avalanche_start_zones': [['1000-1160', '31-35'],
#    ['1240-1310', '32-34'],
#    ['1455-1535', '40-45'],
#    ['1535-1579', ' grad 3']],
#   'max_steepness': 45,
#   'parking_location': 'Langesæterdalen',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': 'Stegjern og isøks. Litt klatreutstyr kan komme godt med mot toppen.',
#   'elevation': 1219,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 47,
#    'name': 'Store Brekketind',
#    'altitude': 1579,
#    'area': 'Rånahalvøya',
#    'routes': [2, 105]}},
#  {'id': 3,
#   'date_created': '2023-04-15T06:40:21.737Z',
#   'date_updated': None,
#   'aspect': ['NV'],
#   'name': 'Nordvestflanken',
#   'dangers': 'Stup i østsida og hammere i nordsida når du har passert 1370 m',
#   'comment': 'Utsatt travers over konveks mellom 1330-1370',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.720328, 62.211534],
#      [6.724105, 62.211874],
#      [6.726637, 62.211354],
#      [6.729813, 62.210454],
#      [6.732473, 62.209814],
#      [6.735091, 62.208773],
#      [6.739511, 62.207813],
#      [6.74037, 62.206952],
#      [6.740885, 62.206672],
#      [6.743202, 62.208313],
#      [6.74479, 62.208413],
#      [6.745477, 62.207232],
#      [6.747108, 62.206512],
#      [6.742001, 62.204551]]}},
#   'max_start_altitude': 360,
#   'avalanche_start_zones': [['1000-1265', '33-38'],
#    ['1330-1370', '32-38'],
#    ['1440-1500', '31-33']],
#   'max_steepness': 38,
#   'parking_location': 'Langesæterdalen',
#   'exposure': 'E2',
#   'difficulty': 'V',
#   'equipment': None,
#   'elevation': 1249,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 41,
#    'name': 'Nordre Smørskredtind',
#    'altitude': 1609,
#    'area': 'Rånahalvøya',
#    'routes': [3]}},
#  {'id': 4,
#   'date_created': '2023-04-15T06:40:21.741Z',
#   'date_updated': None,
#   'aspect': ['SØ', 'N'],
#   'name': 'Normalveien',
#   'dangers': 'Renner',
#   'comment': 'To lange, bratte renner med motsatt himmelretning. ',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.719985, 62.211374],
#      [6.722474, 62.208873],
#      [6.725693, 62.207072],
#      [6.727924, 62.205731],
#      [6.729212, 62.204991],
#      [6.729341, 62.204251],
#      [6.730628, 62.20385],
#      [6.732044, 62.20359],
#      [6.734061, 62.20321],
#      [6.736979, 62.202249],
#      [6.737709, 62.201609],
#      [6.738482, 62.199788],
#      [6.737795, 62.199307],
#      [6.735048, 62.199527],
#      [6.733117, 62.200148],
#      [6.732302, 62.199908]]}},
#   'max_start_altitude': 360,
#   'avalanche_start_zones': [['1100-1260', '32-35'],
#    ['1260-1440', '37-45 1450-1430', ' 32-33']],
#   'max_steepness': 46,
#   'parking_location': 'Langesæterdalen',
#   'exposure': 'E3',
#   'difficulty': 'MV',
#   'equipment': 'Stegjern og isøks',
#   'elevation': 1271,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 48,
#    'name': 'Store Smørskredtind',
#    'altitude': 1631,
#    'area': 'Rånahalvøya',
#    'routes': [4, 6, 106]}},
#  {'id': 5,
#   'date_created': '2023-04-15T06:40:21.745Z',
#   'date_updated': None,
#   'aspect': ['SØ', 'Ø'],
#   'name': 'Normalveien',
#   'dangers': 'Ruta går i en traktformasjon hele veien, elvegjøl opp til 220.',
#   'comment': 'Mye microterreng opp til 400 m',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.399601, 62.317338],
#      [6.399579, 62.317547],
#      [6.398335, 62.317298],
#      [6.397326, 62.317139],
#      [6.396403, 62.316949],
#      [6.39533, 62.3168],
#      [6.394558, 62.31657],
#      [6.393871, 62.316371],
#      [6.393142, 62.316132],
#      [6.392562, 62.315932],
#      [6.39179, 62.315763],
#      [6.390545, 62.315504],
#      [6.389644, 62.315314],
#      [6.388786, 62.315554],
#      [6.387885, 62.315524],
#      [6.386983, 62.315514],
#      [6.386404, 62.314736],
#      [6.384902, 62.314307],
#      [6.383486, 62.313909],
#      [6.381383, 62.31358],
#      [6.379731, 62.313291],
#      [6.378336, 62.313121],
#      [6.377349, 62.312981],
#      [6.376791, 62.312762],
#      [6.375504, 62.313001],
#      [6.374173, 62.313211],
#      [6.372843, 62.313211],
#      [6.37074, 62.313041],
#      [6.368659, 62.312852],
#      [6.36692, 62.312692],
#      [6.364946, 62.312553],
#      [6.362822, 62.312204],
#      [6.361427, 62.312563],
#      [6.359947, 62.312752],
#      [6.358273, 62.312852],
#      [6.355205, 62.312932],
#      [6.352715, 62.313151],
#      [6.351128, 62.313061],
#      [6.34954, 62.312752],
#      [6.348606, 62.312568],
#      [6.34807, 62.312632],
#      [6.347769, 62.312343],
#      [6.347297, 62.312184],
#      [6.346622, 62.312204],
#      [6.345334, 62.312478],
#      [6.344551, 62.312702],
#      [6.342684, 62.314058],
#      [6.342051, 62.314098]]}},
#   'max_start_altitude': 7,
#   'avalanche_start_zones': [['175-195', '30'],
#    ['795-845', '30'],
#    ['980-1080', '30'],
#    ['1110-1222', '32-39'],
#    ['1234-1271', '30'],
#    ['1280-1404', '33-37']],
#   'max_steepness': 38,
#   'parking_location': 'Parkeringslomme rett S for skredtunnel',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': None,
#   'elevation': 1407,
#   'kast': 3,
#   'dry_snow': True,
#   'is_couloir': False,
#   'peak_id': {'id': 42,
#    'name': 'Randers topp',
#    'altitude': 1414,
#    'area': 'Kolåshalvøya',
#    'routes': [0, 5]}},
#  {'id': 6,
#   'date_created': '2023-04-15T06:40:21.750Z',
#   'date_updated': None,
#   'aspect': ['SØ', 'S', 'SV'],
#   'name': 'Sørøstrenna',
#   'dangers': 'Renne. Elvegjøl i inngangen av Tverrdalen. Tett skog under 600.',
#   'comment': 'Vanligvis lite snø i skogen opp til 500 m.',
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.720564, 62.180937],
#      [6.721509, 62.180657],
#      [6.723053, 62.180697],
#      [6.725113, 62.180427],
#      [6.729169, 62.179685],
#      [6.732645, 62.179555],
#      [6.734469, 62.179916],
#      [6.735198, 62.180417],
#      [6.737237, 62.181037],
#      [6.737752, 62.181458],
#      [6.73831, 62.181979],
#      [6.739619, 62.18301],
#      [6.739855, 62.183501],
#      [6.740348, 62.183991],
#      [6.74125, 62.184822],
#      [6.741915, 62.186254],
#      [6.742773, 62.187155],
#      [6.745648, 62.187956],
#      [6.747751, 62.188957],
#      [6.752257, 62.192621],
#      [6.752644, 62.193902],
#      [6.750498, 62.194843],
#      [6.749039, 62.194943],
#      [6.747622, 62.194683],
#      [6.745691, 62.195003],
#      [6.744747, 62.195164],
#      [6.742601, 62.194883],
#      [6.741357, 62.194883],
#      [6.739812, 62.195364],
#      [6.740026, 62.196145],
#      [6.740026, 62.196885],
#      [6.738954, 62.199247],
#      [6.738256, 62.199427],
#      [6.737645, 62.199452],
#      [6.737108, 62.199417],
#      [6.73654, 62.199482],
#      [6.736218, 62.199552],
#      [6.735799, 62.199507],
#      [6.735274, 62.199572],
#      [6.734909, 62.199637],
#      [6.734437, 62.199778],
#      [6.734222, 62.200063],
#      [6.733181, 62.200378],
#      [6.732752, 62.200188],
#      [6.732098, 62.199828]]}},
#   'max_start_altitude': 115,
#   'avalanche_start_zones': [['300-680', '32-35'],
#    ['1240-1350', '30-33'],
#    ['1350-1600', '40-46']],
#   'max_steepness': 46,
#   'parking_location': 'Norangsdalen. Østsida av bru rett S for Kvislane (Overbrua)',
#   'exposure': 'E3',
#   'difficulty': 'MV',
#   'equipment': 'Stegjern og isøks',
#   'elevation': 1516,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': True,
#   'peak_id': {'id': 48,
#    'name': 'Store Smørskredtind',
#    'altitude': 1631,
#    'area': 'Rånahalvøya',
#    'routes': [4, 6, 106]}},
#  {'id': 7,
#   'date_created': '2023-04-15T06:40:21.753Z',
#   'date_updated': None,
#   'aspect': ['Ø'],
#   'name': 'Normalveien',
#   'dangers': 'Ruta går i en traktformasjon fra 210-570, mange små klipper/søkkformasjoner fra 210-570, eksponert travers mellom 1010-1080 (flanken går over i konveks med bratt terreng/stup under.',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.281991, 62.241111],
#      [6.281369, 62.241371],
#      [6.281154, 62.24169],
#      [6.281025, 62.242],
#      [6.280789, 62.24243],
#      [6.28036, 62.24279],
#      [6.28006, 62.243],
#      [6.279716, 62.24311],
#      [6.279352, 62.243269],
#      [6.279116, 62.243559],
#      [6.278558, 62.243679],
#      [6.277914, 62.243719],
#      [6.277163, 62.243769],
#      [6.276519, 62.243769],
#      [6.275661, 62.243769],
#      [6.275146, 62.243909],
#      [6.274502, 62.243819],
#      [6.273794, 62.243729],
#      [6.273108, 62.243639],
#      [6.272378, 62.243489],
#      [6.271262, 62.243379],
#      [6.270254, 62.243299],
#      [6.269417, 62.243229],
#      [6.268923, 62.243199],
#      [6.268322, 62.243259],
#      [6.267893, 62.243399],
#      [6.267335, 62.243319],
#      [6.266928, 62.243179],
#      [6.266541, 62.24291],
#      [6.26637, 62.24244],
#      [6.265919, 62.24214],
#      [6.265254, 62.24207],
#      [6.264138, 62.24203],
#      [6.262915, 62.24196],
#      [6.261864, 62.24196],
#      [6.260555, 62.24203],
#      [6.259439, 62.24239],
#      [6.258945, 62.24297],
#      [6.258667, 62.243389],
#      [6.258388, 62.244019],
#      [6.258109, 62.244688],
#      [6.25577, 62.245168],
#      [6.254718, 62.245408],
#      [6.253645, 62.245608],
#      [6.252723, 62.245698],
#      [6.251693, 62.245678],
#      [6.250899, 62.245678],
#      [6.250062, 62.245548],
#      [6.249311, 62.245458],
#      [6.248796, 62.245488],
#      [6.248302, 62.245648],
#      [6.248088, 62.245898],
#      [6.247659, 62.246187],
#      [6.247444, 62.246317],
#      [6.24723, 62.246547],
#      [6.247294, 62.246807],
#      [6.247551, 62.247017],
#      [6.247187, 62.247167],
#      [6.246436, 62.247147],
#      [6.246092, 62.247376],
#      [6.245942, 62.247596]]}},
#   'max_start_altitude': 140,
#   'avalanche_start_zones': [['475-640', '30'],
#    ['975-1062', '30-38'],
#    ['975-1080', '30-37'],
#    ['1080-1130', '40-45']],
#   'max_steepness': 45,
#   'parking_location': 'Romedalen. Ved bru rett sør for Årsetersætra',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': 'Stegjern og isøks',
#   'elevation': 990,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 29,
#    'name': 'Kjerringa',
#    'altitude': 1130,
#    'area': 'Kolåshalvøya',
#    'routes': [7]}},
#  {'id': 8,
#   'date_created': '2023-04-15T06:40:21.757Z',
#   'date_updated': None,
#   'aspect': ['S', 'Ø'],
#   'name': 'Normalveien',
#   'dangers': 'Ruta går i en traktformasjon fra 210-570, mange små klipper/søkkformasjoner fra 210-570',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.281948, 62.241051],
#      [6.281304, 62.241381],
#      [6.281025, 62.24175],
#      [6.280875, 62.24221],
#      [6.280725, 62.24253],
#      [6.280317, 62.24278],
#      [6.27991, 62.243],
#      [6.279416, 62.243279],
#      [6.279266, 62.243569],
#      [6.278193, 62.243739],
#      [6.277184, 62.243749],
#      [6.276305, 62.243809],
#      [6.275811, 62.243719],
#      [6.275232, 62.243939],
#      [6.27476, 62.243919],
#      [6.273043, 62.243599],
#      [6.271241, 62.243349],
#      [6.270082, 62.243269],
#      [6.268923, 62.243179],
#      [6.268215, 62.243219],
#      [6.267829, 62.243449],
#      [6.267228, 62.243329],
#      [6.266863, 62.24313],
#      [6.266198, 62.24228],
#      [6.265275, 62.24199],
#      [6.262357, 62.2419],
#      [6.260362, 62.24196],
#      [6.259117, 62.24249],
#      [6.258709, 62.243199],
#      [6.258409, 62.244049],
#      [6.25828, 62.244578],
#      [6.256435, 62.245128],
#      [6.255534, 62.245378],
#      [6.254504, 62.245558],
#      [6.25416, 62.245848],
#      [6.254182, 62.246267],
#      [6.253839, 62.246947],
#      [6.253002, 62.247456],
#      [6.252658, 62.247876],
#      [6.252615, 62.248336],
#      [6.252723, 62.248735],
#      [6.253324, 62.248915],
#      [6.253903, 62.248925],
#      [6.255051, 62.249295],
#      [6.255652, 62.249555],
#      [6.256188, 62.249689],
#      [6.256489, 62.249759],
#      [6.257068, 62.249984],
#      [6.257433, 62.250119],
#      [6.25754, 62.250274],
#      [6.257299, 62.250364],
#      [6.256987, 62.250456],
#      [6.256505, 62.250584]]}},
#   'max_start_altitude': 140,
#   'avalanche_start_zones': [['475-640', '30'], ['980-1030', '32-38']],
#   'max_steepness': 38,
#   'parking_location': 'Romedalen. Ved bru rett sør for Årsetersætra',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': None,
#   'elevation': 922,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 40,
#    'name': 'Mannen',
#    'altitude': 1062,
#    'area': 'Kolåshalvøya',
#    'routes': [8]}},
#  {'id': 9,
#   'date_created': '2023-04-15T06:40:21.761Z',
#   'date_updated': None,
#   'aspect': ['SV'],
#   'name': 'Nøvedalen',
#   'dangers': 'Skrenter i inngangen av Nøvedalen',
#   'comment': 'Vestsida har ofte lite snø',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.379623, 62.253381],
#      [6.380053, 62.252582],
#      [6.382327, 62.251862],
#      [6.383829, 62.251023],
#      [6.383786, 62.250364],
#      [6.382971, 62.249924],
#      [6.383314, 62.249265],
#      [6.384645, 62.248825],
#      [6.386833, 62.248306],
#      [6.388893, 62.248046],
#      [6.390738, 62.247886],
#      [6.393142, 62.248206],
#      [6.394687, 62.247686],
#      [6.403227, 62.24191],
#      [6.405458, 62.239792],
#      [6.406531, 62.237373],
#      [6.407003, 62.235074],
#      [6.411381, 62.231515],
#      [6.413827, 62.230605],
#      [6.415415, 62.230245],
#      [6.417797, 62.230335],
#      [6.419556, 62.230445],
#      [6.420779, 62.231305],
#      [6.42241, 62.232995],
#      [6.430221, 62.234924],
#      [6.431808, 62.233394],
#      [6.432645, 62.232985],
#      [6.432903, 62.232305],
#      [6.433246, 62.231745],
#      [6.433783, 62.231135],
#      [6.434748, 62.230435]]}},
#   'max_start_altitude': 280,
#   'avalanche_start_zones': [['480-550', '32-35'],
#    ['870-1310', 'gjennomsnitt på 36']],
#   'max_steepness': 38,
#   'parking_location': 'Kraftverket, Standaleidet',
#   'exposure': 'E3',
#   'difficulty': 'V',
#   'equipment': 'Stegjern og isøks.',
#   'elevation': 1064,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 23,
#    'name': 'Dalegubben',
#    'altitude': 1344,
#    'area': 'Kolåshalvøya',
#    'routes': [9, 13]}},
#  {'id': 10,
#   'date_created': '2023-04-15T06:40:21.765Z',
#   'date_updated': None,
#   'aspect': ['Ø', 'N'],
#   'name': 'Normalveien',
#   'dangers': None,
#   'comment': 'Eksponert egg mot toppen.',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.226501, 62.299379],
#      [6.227274, 62.298501],
#      [6.227789, 62.298142],
#      [6.228476, 62.297424],
#      [6.227875, 62.296307],
#      [6.228819, 62.295509],
#      [6.23105, 62.293992],
#      [6.23311, 62.293474],
#      [6.236115, 62.293394],
#      [6.237359, 62.292606],
#      [6.237402, 62.292147],
#      [6.237831, 62.292017],
#      [6.23826, 62.291827],
#      [6.23929, 62.291678],
#      [6.23929, 62.291329],
#      [6.238947, 62.291109],
#      [6.238539, 62.290939],
#      [6.238453, 62.29071],
#      [6.238861, 62.290231],
#      [6.239676, 62.289642],
#      [6.240106, 62.289323],
#      [6.240513, 62.289044],
#      [6.240985, 62.287976],
#      [6.241157, 62.286938],
#      [6.240942, 62.28594],
#      [6.240835, 62.285232],
#      [6.236823, 62.284004],
#      [6.23678, 62.283176],
#      [6.236544, 62.282517],
#      [6.23605, 62.281998],
#      [6.235085, 62.28097],
#      [6.234376, 62.280531],
#      [6.234055, 62.279947],
#      [6.233786, 62.279593],
#      [6.233368, 62.279214],
#      [6.232842, 62.27872],
#      [6.232241, 62.278355],
#      [6.231791, 62.278191],
#      [6.231233, 62.278096],
#      [6.230739, 62.278011],
#      [6.230214, 62.277896],
#      [6.22972, 62.277806],
#      [6.229334, 62.277756],
#      [6.229076, 62.277746],
#      [6.228658, 62.277806],
#      [6.228476, 62.277821],
#      [6.228057, 62.277741],
#      [6.227617, 62.277647],
#      [6.227242, 62.277542],
#      [6.226834, 62.277467],
#      [6.226265, 62.277387],
#      [6.225922, 62.277327],
#      [6.2256, 62.277157],
#      [6.2253, 62.277018],
#      [6.225117, 62.276903],
#      [6.224817, 62.276723]]}},
#   'max_start_altitude': 400,
#   'avalanche_start_zones': [['540-620'], ['30-33'], ['960-1233', '32-38']],
#   'max_steepness': 38,
#   'parking_location': 'Vartdalssætra',
#   'exposure': 'E3',
#   'difficulty': 'V',
#   'equipment': 'Stegjern og isøks',
#   'elevation': 833,
#   'kast': 3,
#   'dry_snow': True,
#   'is_couloir': False,
#   'peak_id': {'id': 53,
#    'name': 'Åvasstind',
#    'altitude': 1233,
#    'area': 'Kolåshalvøya',
#    'routes': [10, 83, 103]}},
#  {'id': 11,
#   'date_created': '2023-04-15T06:40:21.769Z',
#   'date_updated': None,
#   'aspect': ['NV'],
#   'name': 'Normalveien',
#   'dangers': 'Bratt/eksponert topprygg',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.277184, 62.283595],
#      [6.279073, 62.285811],
#      [6.281176, 62.286549],
#      [6.283493, 62.286828],
#      [6.284137, 62.287846],
#      [6.288857, 62.289842],
#      [6.291561, 62.290061],
#      [6.293621, 62.289483],
#      [6.296668, 62.289642],
#      [6.298728, 62.287287],
#      [6.301603, 62.287208],
#      [6.303792, 62.286589],
#      [6.305809, 62.285092],
#      [6.305594, 62.284433],
#      [6.308126, 62.284074],
#      [6.307869, 62.283735],
#      [6.307182, 62.283415],
#      [6.307016, 62.283311],
#      [6.306351, 62.283178],
#      [6.305519, 62.283126],
#      [6.305144, 62.283191],
#      [6.304607, 62.283291],
#      [6.304505, 62.283271],
#      [6.304361, 62.283306]]}},
#   'max_start_altitude': 375,
#   'avalanche_start_zones': [['720-740', '30-35'], ['1050-1295', '35-40']],
#   'max_steepness': '',
#   'parking_location': None,
#   'exposure': 'E3',
#   'difficulty': 'V',
#   'equipment': None,
#   'elevation': 920,
#   'kast': 3,
#   'dry_snow': True,
#   'is_couloir': False,
#   'peak_id': {'id': 44,
#    'name': 'Romedalstind',
#    'altitude': 1295,
#    'area': 'Kolåshalvøya',
#    'routes': [11]}},
#  {'id': 12,
#   'date_created': '2023-04-15T06:40:21.772Z',
#   'date_updated': None,
#   'aspect': ['Ø'],
#   'name': 'Østflanken',
#   'dangers': 'Bekkedal i inngangen av Litjedalen',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.437516, 62.20389],
#      [6.435885, 62.204311],
#      [6.434641, 62.204671],
#      [6.433654, 62.205131],
#      [6.432495, 62.206012],
#      [6.43095, 62.206932],
#      [6.42992, 62.207773],
#      [6.428847, 62.208273],
#      [6.427302, 62.208753],
#      [6.425757, 62.209273],
#      [6.42477, 62.209814],
#      [6.424084, 62.210414],
#      [6.423311, 62.211014],
#      [6.423054, 62.211294],
#      [6.423054, 62.211874],
#      [6.422753, 62.212815],
#      [6.422324, 62.213295],
#      [6.421337, 62.213935],
#      [6.420436, 62.214095],
#      [6.419363, 62.214415],
#      [6.418247, 62.214555],
#      [6.415715, 62.214995],
#      [6.415715, 62.213695],
#      [6.414514, 62.213435],
#      [6.412625, 62.213175],
#      [6.410995, 62.212955],
#      [6.409149, 62.212955],
#      [6.407475, 62.213035],
#      [6.406059, 62.213215],
#      [6.404815, 62.213315],
#      [6.40357, 62.213555],
#      [6.402411, 62.213615],
#      [6.401038, 62.213655],
#      [6.399579, 62.213835],
#      [6.398077, 62.213875],
#      [6.397176, 62.213935],
#      [6.396275, 62.214335],
#      [6.395459, 62.214815],
#      [6.394043, 62.215175],
#      [6.393142, 62.215435],
#      [6.392369, 62.215615],
#      [6.39164, 62.215816],
#      [6.390395, 62.216036],
#      [6.389451, 62.216236],
#      [6.388764, 62.216576],
#      [6.388378, 62.216756],
#      [6.388121, 62.216956],
#      [6.387649, 62.217296]]}},
#   'max_start_altitude': 100,
#   'avalanche_start_zones': [['760-800', '30'], ['1140-1230', '32-37']],
#   'max_steepness': 37,
#   'parking_location': None,
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': None,
#   'elevation': 1230,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 13,
#    'name': 'Grøtdalstind',
#    'altitude': 1330,
#    'area': 'Kolåshalvøya',
#    'routes': [12, 73, 74]}},
#  {'id': 13,
#   'date_created': '2023-04-15T06:40:21.778Z',
#   'date_updated': None,
#   'aspect': ['S'],
#   'name': 'Skondalen',
#   'dangers': '450:Elvegjøl',
#   'comment': 'Vanskelighetsgrad V om man kjører ski fra toppen. ',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.47584, 62.211694],
#      [6.473823, 62.212154],
#      [6.47305, 62.211874],
#      [6.471677, 62.211814],
#      [6.47202, 62.212134],
#      [6.472106, 62.212515],
#      [6.471419, 62.212435],
#      [6.471548, 62.212695],
#      [6.47069, 62.212935],
#      [6.469831, 62.213315],
#      [6.469316, 62.213575],
#      [6.468072, 62.213635],
#      [6.465883, 62.213375],
#      [6.464553, 62.213955],
#      [6.463652, 62.214415],
#      [6.462235, 62.215035],
#      [6.46142, 62.215215],
#      [6.460476, 62.215315],
#      [6.459918, 62.215715],
#      [6.459446, 62.216016],
#      [6.458158, 62.216396],
#      [6.457429, 62.216836],
#      [6.457386, 62.217396],
#      [6.457429, 62.217956],
#      [6.455884, 62.218336],
#      [6.454768, 62.218516],
#      [6.454296, 62.218616],
#      [6.454039, 62.218856],
#      [6.452837, 62.218876],
#      [6.452193, 62.218896],
#      [6.451936, 62.219696],
#      [6.451249, 62.220756],
#      [6.450906, 62.221516],
#      [6.450477, 62.222156],
#      [6.449661, 62.222516],
#      [6.448674, 62.222776],
#      [6.448073, 62.222976],
#      [6.447773, 62.223556],
#      [6.446872, 62.224316],
#      [6.4464, 62.224816],
#      [6.445713, 62.225316],
#      [6.444855, 62.225796],
#      [6.443267, 62.226436],
#      [6.4417, 62.227106],
#      [6.441486, 62.227526],
#      [6.440091, 62.227706],
#      [6.438611, 62.227996],
#      [6.437366, 62.228776],
#      [6.437044, 62.229356],
#      [6.437302, 62.230075],
#      [6.437151, 62.230235],
#      [6.436615, 62.230355],
#      [6.436079, 62.230445],
#      [6.435585, 62.230505],
#      [6.435027, 62.230515],
#      [6.434619, 62.230525],
#      [6.434727, 62.230375]]}},
#   'max_start_altitude': 0,
#   'avalanche_start_zones': [['850-900', '30'],
#    ['1130-1160', '32'],
#    ['1170-1240', '34-39'],
#    ['1250-1340', '35-43']],
#   'max_steepness': 43,
#   'parking_location': 'Sæbø',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': 'Stegjern og isøks.',
#   'elevation': None,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 23,
#    'name': 'Dalegubben',
#    'altitude': 1344,
#    'area': 'Kolåshalvøya',
#    'routes': [9, 13]}},
#  {'id': 14,
#   'date_created': '2023-04-15T06:40:21.782Z',
#   'date_updated': None,
#   'aspect': ['V'],
#   'name': 'Nordvestflanken',
#   'dangers': None,
#   'comment': 'Veien er vanligvis ikke brøytet',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.466141, 62.110347],
#      [6.463051, 62.114442],
#      [6.461334, 62.118456],
#      [6.459961, 62.122068],
#      [6.459875, 62.124356],
#      [6.459875, 62.126001],
#      [6.460819, 62.127526],
#      [6.464167, 62.128449],
#      [6.468192, 62.129536],
#      [6.470595, 62.130098],
#      [6.473685, 62.1307],
#      [6.476947, 62.130981],
#      [6.479007, 62.131061],
#      [6.483298, 62.131141],
#      [6.484157, 62.130901]]}},
#   'max_start_altitude': 450,
#   'avalanche_start_zones': [['900-1000', '30'], ['1090-1284', '32-37']],
#   'max_steepness': 37,
#   'parking_location': 'Bakkedalen',
#   'exposure': 'E2',
#   'difficulty': 'V',
#   'equipment': 'Stegjern og isøks',
#   'elevation': 962,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 24,
#    'name': 'Dukhornet',
#    'altitude': 1412,
#    'area': 'Kolåshalvøya',
#    'routes': [14, 15]}},
#  {'id': 15,
#   'date_created': '2023-04-15T06:40:21.787Z',
#   'date_updated': None,
#   'aspect': ['S', 'Ø'],
#   'name': 'Normalveien',
#   'dangers': 'Store skredbaner må krysses innover Russadalen, Elvedal i bunnen av Russadalen, ',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.528025, 62.11123],
#      [6.52442, 62.114964],
#      [6.519098, 62.116449],
#      [6.516008, 62.117292],
#      [6.512747, 62.117413],
#      [6.511116, 62.119018],
#      [6.509485, 62.120102],
#      [6.50794, 62.121868],
#      [6.503735, 62.12255],
#      [6.50013, 62.121547],
#      [6.493092, 62.124276],
#      [6.488285, 62.124276],
#      [6.484251, 62.123112],
#      [6.484337, 62.125801],
#      [6.484251, 62.127887],
#      [6.485796, 62.129372]]}},
#   'max_start_altitude': 310,
#   'avalanche_start_zones': [['450-550', '30'],
#    ['940-1135', ' Enkeltheng opp mot 35']],
#   'max_steepness': 35,
#   'parking_location': 'Bakkedalen',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': None,
#   'elevation': 1102,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 24,
#    'name': 'Dukhornet',
#    'altitude': 1412,
#    'area': 'Kolåshalvøya',
#    'routes': [14, 15]}},
#  {'id': 16,
#   'date_created': '2023-04-15T06:40:21.790Z',
#   'date_updated': None,
#   'aspect': ['V'],
#   'name': 'Normalveien',
#   'dangers': 'Store skredbaner må krysses innover Russadalen, Elvedal i bunnen av Russadalen, ',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.507779, 62.121894, 755.5],
#      [6.507769, 62.123593],
#      [6.509056, 62.125118],
#      [6.511717, 62.126563],
#      [6.514549, 62.126683],
#      [6.517296, 62.125841],
#      [6.521587, 62.127205]]}},
#   'max_start_altitude': 310,
#   'avalanche_start_zones': [['450-550', '30']],
#   'max_steepness': 30,
#   'parking_location': 'Bakkedalen',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': None,
#   'elevation': 718,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 30,
#    'name': 'Kjerringkjeftane',
#    'altitude': 1028,
#    'area': 'Kolåshalvøya',
#    'routes': [16, 17]}},
#  {'id': 17,
#   'date_created': '2023-04-15T06:40:21.793Z',
#   'date_updated': None,
#   'aspect': ['S'],
#   'name': 'Sørflanken',
#   'dangers': 'Elvedal i bunnen av Russadalen',
#   'comment': 'Jo lengre ned mot elvedalen man kjører, jo vanskeligere blir det å komme tilbake til opp-sporet. ',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.521587, 62.127205, 1017.099976],
#      [6.518197, 62.118797]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': [['660-890', '34-38']],
#   'max_steepness': 38,
#   'parking_location': None,
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': None,
#   'elevation': None,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 30,
#    'name': 'Kjerringkjeftane',
#    'altitude': 1028,
#    'area': 'Kolåshalvøya',
#    'routes': [16, 17]}},
#  {'id': 18,
#   'date_created': '2023-04-15T06:40:21.797Z',
#   'date_updated': None,
#   'aspect': ['Ø', 'SØ'],
#   'name': 'Normalveien',
#   'dangers': None,
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.375933, 62.295668],
#      [6.361256, 62.292995],
#      [6.356535, 62.291159],
#      [6.353273, 62.291638],
#      [6.350012, 62.291518],
#      [6.346407, 62.293553],
#      [6.334305, 62.29483],
#      [6.334848, 62.297266],
#      [6.333103, 62.298242],
#      [6.330099, 62.300676],
#      [6.327567, 62.300915],
#      [6.325765, 62.300955],
#      [6.324134, 62.300855],
#      [6.321859, 62.300297],
#      [6.319585, 62.299918],
#      [6.317825, 62.300177],
#      [6.315293, 62.299539]]}},
#   'max_start_altitude': 190,
#   'avalanche_start_zones': [['930-950', '30-35'], ['1030-1120', '30-35']],
#   'max_steepness': '',
#   'parking_location': None,
#   'exposure': 'E2',
#   'difficulty': 'V',
#   'equipment': None,
#   'elevation': 942,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 18,
#    'name': 'Svinetind',
#    'altitude': 1132,
#    'area': 'Kolåshalvøya',
#    'routes': [18]}},
#  {'id': 19,
#   'date_created': '2023-04-15T06:40:21.800Z',
#   'date_updated': None,
#   'aspect': ['SØ', 'Ø'],
#   'name': 'Normalveien',
#   'dangers': None,
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.444898, 62.081707],
#      [6.443181, 62.082913],
#      [6.44155, 62.083275],
#      [6.43889, 62.083837],
#      [6.437001, 62.084239],
#      [6.435199, 62.084561],
#      [6.43374, 62.084741],
#      [6.432238, 62.084581],
#      [6.430736, 62.08446],
#      [6.428933, 62.084319],
#      [6.426873, 62.08434],
#      [6.424727, 62.08442],
#      [6.423697, 62.084922],
#      [6.422839, 62.085605],
#      [6.421852, 62.085987],
#      [6.419363, 62.086168],
#      [6.417646, 62.086228],
#      [6.415329, 62.086288],
#      [6.413612, 62.08657],
#      [6.412582, 62.086911],
#      [6.412196, 62.087655],
#      [6.411896, 62.088498],
#      [6.411638, 62.089121],
#      [6.411595, 62.089945],
#      [6.411638, 62.090326],
#      [6.411896, 62.091572],
#      [6.409879, 62.092295],
#      [6.408119, 62.092697],
#      [6.406617, 62.092918],
#      [6.404986, 62.093159],
#      [6.403399, 62.0934],
#      [6.401854, 62.093741],
#      [6.400094, 62.094042],
#      [6.401381, 62.095448],
#      [6.399279, 62.093319],
#      [6.398463, 62.092616],
#      [6.398077, 62.092114],
#      [6.397862, 62.091491],
#      [6.397948, 62.09113],
#      [6.397991, 62.090648]]}},
#   'max_start_altitude': 360,
#   'avalanche_start_zones': [['950-120', '32-37'], ['1290-1310', '30-34']],
#   'max_steepness': 37,
#   'parking_location': None,
#   'exposure': 'E1',
#   'difficulty': 'GV',
#   'equipment': None,
#   'elevation': 1030,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 6,
#    'name': 'Sandegga',
#    'altitude': 1390,
#    'area': 'Kolåshalvøya',
#    'routes': [19, 40]}},
#  {'id': 20,
#   'date_created': '2023-04-15T06:40:21.804Z',
#   'date_updated': None,
#   'aspect': ['SV'],
#   'name': 'Sørvestsida',
#   'dangers': 'Renne',
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.700888, 62.226311],
#      [6.700373, 62.225921],
#      [6.699976, 62.225656],
#      [6.699407, 62.225406],
#      [6.698956, 62.225131],
#      [6.698409, 62.224846],
#      [6.697905, 62.224501],
#      [6.696666, 62.223704],
#      [6.696548, 62.223406],
#      [6.696553, 62.223109],
#      [6.696677, 62.222854],
#      [6.69651, 62.222516],
#      [6.696162, 62.222291],
#      [6.693206, 62.221036],
#      [6.692197, 62.220306],
#      [6.692369, 62.219406],
#      [6.692626, 62.218886],
#      [6.693013, 62.218246],
#      [6.692766, 62.217646],
#      [6.692106, 62.216611],
#      [6.689783, 62.21579]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': [['950-980', '30'],
#    ['1100-1325', '34-37'],
#    ['1325-1470', '38-45']],
#   'max_steepness': 45,
#   'parking_location': None,
#   'exposure': 'E3',
#   'difficulty': 'V',
#   'equipment': None,
#   'elevation': None,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 36,
#    'name': 'Lille Brekketind',
#    'altitude': 1550,
#    'area': 'Rånahalvøya',
#    'routes': [1, 20]}},
#  {'id': 21,
#   'date_created': '2023-04-15T06:40:21.807Z',
#   'date_updated': None,
#   'aspect': ['Ø'],
#   'name': 'Breen',
#   'dangers': 'Smal passasje/elvegjøl i inngangen til Kvanndalen, Bratt under konveks 1320-1360, Bresprekker',
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.351299, 62.250923],
#      [6.350827, 62.253041],
#      [6.349883, 62.25404],
#      [6.349883, 62.25464],
#      [6.350141, 62.255419],
#      [6.350183, 62.256478],
#      [6.349926, 62.257696],
#      [6.349583, 62.258535],
#      [6.349368, 62.259015],
#      [6.348939, 62.259434],
#      [6.347523, 62.260113],
#      [6.345077, 62.260952],
#      [6.34203, 62.261691],
#      [6.338339, 62.261771],
#      [6.336279, 62.261871],
#      [6.335335, 62.261931],
#      [6.334004, 62.262291],
#      [6.332974, 62.261771],
#      [6.332116, 62.261791],
#      [6.331515, 62.262211],
#      [6.329713, 62.261711],
#      [6.329241, 62.261591],
#      [6.328297, 62.26291],
#      [6.327481, 62.263269],
#      [6.326323, 62.263629],
#      [6.32525, 62.263789],
#      [6.323533, 62.263868],
#      [6.322289, 62.263509],
#      [6.320486, 62.263489],
#      [6.319413, 62.263908],
#      [6.317697, 62.263669],
#      [6.315422, 62.263409],
#      [6.313405, 62.26299],
#      [6.311603, 62.26235],
#      [6.310487, 62.261532],
#      [6.310143, 62.260772],
#      [6.310658, 62.260253],
#      [6.312976, 62.259434],
#      [6.313362, 62.259174],
#      [6.312504, 62.258815],
#      [6.310916, 62.258835]]}},
#   'max_start_altitude': 370,
#   'avalanche_start_zones': [['690-760', '30-33'],
#    ['780-835', '31-37'],
#    ['1320-1350', '32-40'],
#    ['1380-1432', '32-46']],
#   'max_steepness': 46,
#   'parking_location': 'Standaleidet',
#   'exposure': 'E2',
#   'difficulty': 'GV',
#   'equipment': 'Stegjern, isøks, breutstyr (ved lite snø)',
#   'elevation': 1062,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 12,
#    'name': 'Kolåstind',
#    'altitude': 1432,
#    'area': 'Kolåshalvøya',
#    'routes': [21, 72]}},
#  {'id': 22,
#   'date_created': '2023-04-15T06:40:21.812Z',
#   'date_updated': None,
#   'aspect': ['SV'],
#   'name': 'Insterenna',
#   'dangers': 'Renneformasjon, bekkedal i kvanndalen, eksponert topprygg.',
#   'comment': 'Fin å kombinere med nedkjøring ned Fladalen.',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.3307, 62.270918],
#      [6.333361, 62.272595],
#      [6.33585, 62.274033],
#      [6.336644, 62.275281],
#      [6.337438, 62.27588],
#      [6.338081, 62.27574],
#      [6.339304, 62.275131],
#      [6.34306, 62.274812],
#      [6.346192, 62.274632],
#      [6.349154, 62.273913],
#      [6.350613, 62.273254],
#      [6.355033, 62.272416],
#      [6.353638, 62.271906],
#      [6.352394, 62.271657],
#      [6.351707, 62.271427],
#      [6.351364, 62.271277],
#      [6.351428, 62.270858],
#      [6.351686, 62.270668]]}},
#   'max_start_altitude': 370,
#   'avalanche_start_zones': [['1030-1150', '34-45'],
#    ['1230-1270', '35'],
#    ['1290-1365', '34-43']],
#   'max_steepness': 45,
#   'parking_location': 'Standaleidet',
#   'exposure': 'E3',
#   'difficulty': 'V',
#   'equipment': 'Stegjern og isøks',
#   'elevation': 995,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': True,
#   'peak_id': {'id': 10,
#    'name': 'Nordre Sætretind',
#    'altitude': 1365,
#    'area': 'Kolåshalvøya',
#    'routes': [22, 23, 81, 95]}},
#  {'id': 23,
#   'date_created': '2023-04-15T06:40:21.816Z',
#   'date_updated': None,
#   'aspect': ['SV'],
#   'name': 'Ytsterenna',
#   'dangers': 'Renneformasjon, bekkedal i kvanndalen.',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.348746, 62.272835],
#      [6.346793, 62.272316],
#      [6.345398, 62.271697],
#      [6.344604, 62.271447],
#      [6.340678, 62.270948],
#      [6.336794, 62.267334]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': [['900-980', '32-34'], ['980-1200', '36-45']],
#   'max_steepness': 45,
#   'parking_location': None,
#   'exposure': 'E3',
#   'difficulty': 'V',
#   'equipment': None,
#   'elevation': None,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': True,
#   'peak_id': {'id': 10,
#    'name': 'Nordre Sætretind',
#    'altitude': 1365,
#    'area': 'Kolåshalvøya',
#    'routes': [22, 23, 81, 95]}},
#  {'id': 24,
#   'date_created': '2023-04-15T06:40:21.819Z',
#   'date_updated': None,
#   'aspect': ['S'],
#   'name': 'Normalveien',
#   'dangers': 'Bekkedal i Vikeskåla. Klipper på østsida av toppflanker.',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.126809, 62.210934],
#      [6.125865, 62.213875],
#      [6.126294, 62.214815],
#      [6.126122, 62.215135],
#      [6.125522, 62.215575],
#      [6.123548, 62.219716],
#      [6.122689, 62.221236],
#      [6.123419, 62.222336],
#      [6.124148, 62.222436],
#      [6.13286, 62.225336],
#      [6.135392, 62.225976],
#      [6.141829, 62.227896],
#      [6.141872, 62.229995],
#      [6.141186, 62.231275],
#      [6.1408, 62.232875],
#      [6.140993, 62.233225],
#      [6.141765, 62.233654],
#      [6.142259, 62.234034],
#      [6.142516, 62.234614],
#      [6.142881, 62.235234],
#      [6.142516, 62.235669]]}},
#   'max_start_altitude': 140,
#   'avalanche_start_zones': [['1050-1303', '35-38']],
#   'max_steepness': 38,
#   'parking_location': 'Vassverket',
#   'exposure': 'E2',
#   'difficulty': 'V',
#   'equipment': 'Stegjern og isøks ',
#   'elevation': 1163,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 4,
#    'name': 'Saudehornet',
#    'altitude': 1303,
#    'area': 'Kolåshalvøya',
#    'routes': [24, 25]}},
#  {'id': 25,
#   'date_created': '2023-04-15T06:40:21.823Z',
#   'date_updated': None,
#   'aspect': ['SV'],
#   'name': 'Sørvestflanken',
#   'dangers': 'Bekkedal i Vikeskåla. Klipper på østsida av toppflanker.',
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.142602, 62.235554],
#      [6.136036, 62.230875],
#      [6.132517, 62.227896],
#      [6.129427, 62.225896],
#      [6.12505, 62.225196],
#      [6.12093, 62.223976],
#      [6.120737, 62.223196],
#      [6.12093, 62.222206],
#      [6.121273, 62.221401],
#      [6.121659, 62.220866],
#      [6.123312, 62.219746]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': [['820-1303', '35-39']],
#   'max_steepness': 39,
#   'parking_location': None,
#   'exposure': 'E2',
#   'difficulty': 'V',
#   'equipment': None,
#   'elevation': None,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 4,
#    'name': 'Saudehornet',
#    'altitude': 1303,
#    'area': 'Kolåshalvøya',
#    'routes': [24, 25]}},
#  {'id': 26,
#   'date_created': '2023-04-15T06:40:21.826Z',
#   'date_updated': None,
#   'aspect': ['NØ'],
#   'name': 'Litle-Skårdalen',
#   'dangers': 'Renne',
#   'comment': 'Avtal henting med ferga eller skyssbåt.',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.469488, 62.16987],
#      [6.471977, 62.171152],
#      [6.475153, 62.171753],
#      [6.479659, 62.173756],
#      [6.481676, 62.174077],
#      [6.485667, 62.175159],
#      [6.488714, 62.176601],
#      [6.49159, 62.178043],
#      [6.492877, 62.178524],
#      [6.49528, 62.178764],
#      [6.497641, 62.179265],
#      [6.499958, 62.179685],
#      [6.503391, 62.180787],
#      [6.505365, 62.181248],
#      [6.507854, 62.181848],
#      [6.511073, 62.182429],
#      [6.512876, 62.182309],
#      [6.514678, 62.182449],
#      [6.51691, 62.18283],
#      [6.518669, 62.18309],
#      [6.520643, 62.18309],
#      [6.522574, 62.18267],
#      [6.524162, 62.181929],
#      [6.525965, 62.181107],
#      [6.526952, 62.180386],
#      [6.528926, 62.180447],
#      [6.530557, 62.180206],
#      [6.532273, 62.179806],
#      [6.533604, 62.179185]]}},
#   'max_start_altitude': 500,
#   'avalanche_start_zones': [['530-565', '30-32'],
#    ['1095-1110', '30'],
#    ['1180-1205', '33-35']],
#   'max_steepness': 35,
#   'parking_location': None,
#   'exposure': 'E1',
#   'difficulty': 'GV',
#   'equipment': None,
#   'elevation': 1040,
#   'kast': 3,
#   'dry_snow': True,
#   'is_couloir': False,
#   'peak_id': {'id': 14,
#    'name': 'Skårasalen',
#    'altitude': 1540,
#    'area': 'Kolåshalvøya',
#    'routes': [26, 50]}},
#  {'id': 27,
#   'date_created': '2023-04-15T06:40:21.830Z',
#   'date_updated': None,
#   'aspect': ['SV'],
#   'name': 'Vestrenna',
#   'dangers': 'Bekkedaler innerst i Kvistaddalen, renneformasjon, tidvis eksponert topprygg.',
#   'comment': 'Fint tur å kombinere med Kjerringøyra og Utolhornet.',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.452494, 62.158829],
#      [6.455712, 62.158067],
#      [6.457987, 62.157626],
#      [6.459532, 62.156824],
#      [6.471806, 62.153777],
#      [6.482191, 62.156263],
#      [6.484337, 62.155962],
#      [6.485624, 62.15512],
#      [6.488843, 62.152494],
#      [6.49322, 62.148044],
#      [6.495452, 62.147613],
#      [6.496546, 62.147703],
#      [6.497447, 62.148034],
#      [6.497962, 62.148405],
#      [6.498756, 62.148746],
#      [6.499443, 62.149026],
#      [6.500173, 62.149427],
#      [6.50131, 62.149878],
#      [6.502018, 62.150189],
#      [6.502533, 62.15048],
#      [6.503413, 62.151191],
#      [6.503048, 62.151773],
#      [6.500816, 62.152334],
#      [6.500087, 62.152745],
#      [6.499743, 62.153346],
#      [6.499357, 62.153848],
#      [6.499164, 62.154449],
#      [6.498907, 62.155311]]}},
#   'max_start_altitude': 500,
#   'avalanche_start_zones': [],
#   'max_steepness': 45,
#   'parking_location': 'Kvistadsætra',
#   'exposure': 'E3',
#   'difficulty': 'MV',
#   'equipment': 'Stegjern, isøks',
#   'elevation': 933,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': True,
#   'peak_id': {'id': 34,
#    'name': 'Kvistadkjerringane ',
#    'altitude': 1433,
#    'area': 'Kolåshalvøya',
#    'routes': [27]}},
#  {'id': 29,
#   'date_created': '2023-04-15T06:40:21.836Z',
#   'date_updated': None,
#   'aspect': ['SØ', 'SV'],
#   'name': 'Sydvestflanken',
#   'dangers': 'Skog, søkkformasjoner og bekkedalen i bunnen av flanken. Hammer under ruta i inngangen til Kvamsetdalen, dype bekkedal i vestflanken på Kjerringøyra.',
#   'comment': '700 m sammenhengende flanke med jevn helning. ',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.529655, 62.145858], [6.513476, 62.138057]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': [['770-1305', '35-38']],
#   'max_steepness': 38,
#   'parking_location': None,
#   'exposure': 'E2',
#   'difficulty': 'V',
#   'equipment': None,
#   'elevation': None,
#   'kast': 3,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 57,
#    'name': 'Kjerringøyra',
#    'altitude': 1414,
#    'area': 'Kolåshalvøya',
#    'routes': [29]}},
#  {'id': 30,
#   'date_created': '2023-04-15T06:40:21.839Z',
#   'date_updated': None,
#   'aspect': ['SV', 'S'],
#   'name': 'Sørvestsida',
#   'dangers': 'Skavl på toppryggen.',
#   'comment': 'Mulig å følge ryggformasjon i terrenget mellom 950-1170. Tidvis eksponert topprygg.',
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
# ...
#   'kast': None,
#   'dry_snow': True,
#   'is_couloir': False,
#   'peak_id': {'id': 62,
#    'name': 'Gulkoppen',
#    'altitude': 1306,
#    'area': 'Hornindal',
#    'routes': [98]}},
#  {'id': 99,
#   'date_created': '2023-04-29T07:54:30.971Z',
#   'date_updated': None,
#   'aspect': ['N'],
#   'name': 'Nordflanken',
#   'dangers': None,
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.876862, 62.034552],
#      [6.877248, 62.034964],
#      [6.876948, 62.035769],
#      [6.878214, 62.037389],
#      [6.878557, 62.038757],
#      [6.878214, 62.040126],
#      [6.876583, 62.042379],
#      [6.875982, 62.04419],
#      [6.873751, 62.045437],
#      [6.873665, 62.045799]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': True,
#   'is_couloir': False,
#   'peak_id': {'id': 63,
#    'name': 'Kalvedalsegga',
#    'altitude': 1465,
#    'area': 'Hornindal',
#    'routes': [99]}},
#  {'id': 100,
#   'date_created': '2023-04-29T07:55:47.904Z',
#   'date_updated': None,
#   'aspect': ['N'],
#   'name': 'Norflanken',
#   'dangers': None,
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.852615, 62.038939],
#      [6.852658, 62.039643],
#      [6.852658, 62.040236],
#      [6.852572, 62.040649],
#      [6.852229, 62.041283],
#      [6.851928, 62.041987],
#      [6.851242, 62.042238],
#      [6.850598, 62.042631],
#      [6.850255, 62.042983],
#      [6.85004, 62.043687],
#      [6.849933, 62.044552],
#      [6.849632, 62.045618],
#      [6.849611, 62.046644],
#      [6.849353, 62.047207],
#      [6.848752, 62.047821],
#      [6.847851, 62.048424],
#      [6.847272, 62.049028]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': True,
#   'is_couloir': False,
#   'peak_id': {'id': 33,
#    'name': 'Kvanngrønakken',
#    'altitude': 1262,
#    'area': 'Hornindal',
#    'routes': [67, 100]}},
#  {'id': 101,
#   'date_created': '2023-04-29T10:58:12.518Z',
#   'date_updated': '2023-04-29T10:59:30.455Z',
#   'aspect': ['NV'],
#   'name': 'Norvestrenna',
#   'dangers': None,
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.212854, 62.326338],
#      [6.215215, 62.325382],
#      [6.216159, 62.324265],
#      [6.217661, 62.323289],
#      [6.218626, 62.322541],
#      [6.218948, 62.322262],
#      [6.219378, 62.321983],
#      [6.219528, 62.321764],
#      [6.219807, 62.321505],
#      [6.220171, 62.321255],
#      [6.220515, 62.321066],
#      [6.220815, 62.320787],
#      [6.220901, 62.320558]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': False,
#   'is_couloir': True,
#   'peak_id': {'id': 64,
#    'name': 'Klovetind',
#    'altitude': 949,
#    'area': 'Kolåshalvøya',
#    'routes': [101]}},
#  {'id': 102,
#   'date_created': '2023-04-29T11:01:51.153Z',
#   'date_updated': None,
#   'aspect': ['N'],
#   'name': 'Nordrenna',
#   'dangers': None,
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.256843, 62.045301],
#      [6.256564, 62.045145],
#      [6.255909, 62.044808],
#      [6.255802, 62.044627],
#      [6.255641, 62.044431],
#      [6.255373, 62.04429],
#      [6.254987, 62.044014],
#      [6.254536, 62.043918],
#      [6.254107, 62.043928],
#      [6.253678, 62.043868],
#      [6.25327, 62.043848],
#      [6.252744, 62.043813],
#      [6.252433, 62.043813],
#      [6.252058, 62.043782],
#      [6.251843, 62.043732],
#      [6.251585, 62.043556],
#      [6.251221, 62.043405],
#      [6.250856, 62.043375]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': True,
#   'is_couloir': True,
#   'peak_id': {'id': 37,
#    'name': 'Litle Eidskyrkja',
#    'altitude': 1243,
#    'area': 'Austefjorden',
#    'routes': [46, 75, 102]}},
#  {'id': 103,
#   'date_created': '2023-04-29T11:04:55.520Z',
#   'date_updated': None,
#   'aspect': ['N'],
#   'name': 'Nordrenna',
#   'dangers': None,
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.216996, 62.280341],
#      [6.216288, 62.279827],
#      [6.215901, 62.279618],
#      [6.215633, 62.279403],
#      [6.215268, 62.279259],
#      [6.215043, 62.279154],
#      [6.214904, 62.279024],
#      [6.214721, 62.278929],
#      [6.214496, 62.278829],
#      [6.214399, 62.278695],
#      [6.214163, 62.278505],
#      [6.21411, 62.27827],
#      [6.214131, 62.278066],
#      [6.214238, 62.277951],
#      [6.214614, 62.277711]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': True,
#   'is_couloir': True,
#   'peak_id': {'id': 53,
#    'name': 'Åvasstind',
#    'altitude': 1233,
#    'area': 'Kolåshalvøya',
#    'routes': [10, 83, 103]}},
#  {'id': 104,
#   'date_created': '2023-04-29T11:10:22.940Z',
#   'date_updated': None,
#   'aspect': ['Ø', 'S'],
#   'name': 'Normalveien',
#   'dangers': None,
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.583772, 62.231515],
#      [6.585231, 62.233614],
#      [6.585789, 62.234934],
#      [6.586175, 62.237713],
#      [6.587334, 62.239592],
#      [6.589265, 62.240871],
#      [6.590939, 62.24235],
#      [6.592484, 62.24281],
#      [6.594715, 62.242935],
#      [6.595852, 62.24299],
#      [6.597118, 62.24298],
#      [6.597548, 62.243139],
#      [6.598481, 62.243229],
#      [6.59906, 62.243314],
#      [6.600208, 62.243329],
#      [6.600938, 62.243589],
#      [6.602912, 62.243969],
#      [6.604371, 62.244489],
#      [6.606045, 62.245288],
#      [6.609221, 62.246947],
#      [6.611323, 62.248126],
#      [6.612911, 62.249185],
#      [6.614242, 62.251383],
#      [6.616387, 62.25466],
#      [6.616988, 62.255878],
#      [6.616902, 62.257117],
#      [6.617417, 62.258415],
#      [6.615529, 62.258595],
#      [6.613297, 62.258475],
#      [6.611409, 62.258196],
#      [6.60995, 62.257836],
#      [6.608748, 62.257556],
#      [6.607504, 62.257257],
#      [6.605701, 62.256937],
#      [6.604586, 62.256518],
#      [6.602612, 62.256178]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 65,
#    'name': 'Urkedalstind',
#    'altitude': 1534,
#    'area': 'Rånahalvøya',
#    'routes': [104]}},
#  {'id': 105,
#   'date_created': '2023-04-29T11:12:21.731Z',
#   'date_updated': None,
#   'aspect': ['NV'],
#   'name': 'Nordvestrenna',
#   'dangers': None,
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.697712, 62.229741],
#      [6.698785, 62.229646],
#      [6.699708, 62.229616],
#      [6.700523, 62.229481],
#      [6.701242, 62.229386],
#      [6.701821, 62.229351],
#      [6.70239, 62.229291],
#      [6.702894, 62.229221],
#      [6.703334, 62.229116]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': False,
#   'is_couloir': True,
#   'peak_id': {'id': 47,
#    'name': 'Store Brekketind',
#    'altitude': 1579,
#    'area': 'Rånahalvøya',
#    'routes': [2, 105]}},
#  {'id': 106,
#   'date_created': '2023-04-29T11:13:44.663Z',
#   'date_updated': None,
#   'aspect': ['NV'],
#   'name': 'Bananen',
#   'dangers': None,
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.718504, 62.20292],
#      [6.72065, 62.202429],
#      [6.72183, 62.202239],
#      [6.723504, 62.201999],
#      [6.724877, 62.201969],
#      [6.726251, 62.201869],
#      [6.727989, 62.201729],
#      [6.728911, 62.201659],
#      [6.729684, 62.201584],
#      [6.73021, 62.201484],
#      [6.730489, 62.201419],
#      [6.730928, 62.201424],
#      [6.731443, 62.201479],
#      [6.73198, 62.201624],
#      [6.732388, 62.201519],
#      [6.732763, 62.201394],
#      [6.733428, 62.201113],
#      [6.733954, 62.200883]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': False,
#   'is_couloir': True,
#   'peak_id': {'id': 48,
#    'name': 'Store Smørskredtind',
#    'altitude': 1631,
#    'area': 'Rånahalvøya',
#    'routes': [4, 6, 106]}},
#  {'id': 107,
#   'date_created': '2023-04-29T11:18:30.115Z',
#   'date_updated': None,
#   'aspect': ['NØ'],
#   'name': 'Nordøstrenna',
#   'dangers': None,
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.650248, 62.245778],
#      [6.649024, 62.245558],
#      [6.648113, 62.245333],
#      [6.64704, 62.245158],
#      [6.646224, 62.245008],
#      [6.645151, 62.244658],
#      [6.644475, 62.244529],
#      [6.643649, 62.244374],
#      [6.643263, 62.244319],
#      [6.642576, 62.244129],
#      [6.642104, 62.243989],
#      [6.641697, 62.243774],
#      [6.641428, 62.243539],
#      [6.641289, 62.243369]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': True,
#   'is_couloir': True,
#   'peak_id': {'id': 66,
#    'name': 'Vellesæterhornet',
#    'altitude': 1511,
#    'area': 'Rånahalvøya',
#    'routes': [107]}},
#  {'id': 108,
#   'date_created': '2023-04-29T11:25:34.717Z',
#   'date_updated': None,
#   'aspect': ['V'],
#   'name': 'Vestrenna',
#   'dangers': None,
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.713794, 62.256882],
#      [6.716037, 62.257042],
#      [6.716595, 62.257137],
#      [6.71726, 62.257132],
#      [6.718354, 62.257297],
#      [6.718966, 62.257456],
#      [6.719685, 62.257701],
#      [6.720221, 62.257901],
#      [6.720264, 62.258021],
#      [6.72042, 62.258098],
#      [6.720704, 62.258121],
#      [6.72131, 62.258116],
#      [6.721696, 62.258233],
#      [6.721669, 62.25832],
#      [6.721702, 62.258498],
#      [6.722249, 62.258698],
#      [6.722823, 62.25871],
#      [6.723204, 62.258837],
#      [6.723488, 62.25886],
#      [6.723804, 62.258767],
#      [6.724228, 62.25881],
#      [6.724545, 62.25891],
#      [6.725543, 62.259204],
#      [6.726143, 62.259514],
#      [6.726787, 62.260063],
#      [6.727345, 62.260043],
#      [6.727924, 62.259983],
#      [6.728193, 62.259934],
#      [6.728472, 62.260023],
#      [6.728826, 62.260058],
#      [6.72919, 62.260103],
#      [6.729308, 62.260218],
#      [6.729641, 62.260178],
#      [6.729909, 62.260168],
#      [6.730038, 62.260303],
#      [6.730263, 62.260443],
#      [6.731164, 62.260508],
#      [6.731712, 62.260543],
#      [6.732216, 62.260533],
#      [6.732548, 62.260583],
#      [6.732827, 62.260882],
#      [6.733117, 62.260997],
#      [6.733589, 62.261042],
#      [6.734104, 62.261152],
#      [6.73463, 62.261227],
#      [6.734995, 62.261207]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': False,
#   'is_couloir': True,
#   'peak_id': {'id': 67,
#    'name': 'Dalmannshornet',
#    'altitude': 1476,
#    'area': 'Rånahalvøya',
#    'routes': [108]}},
#  {'id': 109,
#   'date_created': '2023-04-29T11:29:03.978Z',
#   'date_updated': None,
#   'aspect': ['Ø'],
#   'name': 'Normalveien',
#   'dangers': None,
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.921816, 62.123794],
#      [6.918726, 62.124236],
#      [6.917439, 62.124838],
#      [6.916323, 62.126724],
#      [6.914949, 62.127847],
#      [6.912975, 62.12861],
#      [6.90937, 62.129131],
#      [6.901131, 62.130415],
#      [6.898556, 62.131458],
#      [6.894007, 62.13194],
#      [6.889372, 62.132702],
#      [6.885338, 62.133585],
#      [6.880274, 62.134748],
#      [6.876669, 62.135149],
#      [6.872206, 62.135109],
#      [6.864653, 62.134949],
#      [6.864653, 62.133625],
#      [6.86697, 62.13198]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 68,
#    'name': 'Kvitegga',
#    'altitude': 1489,
#    'area': 'Rånahalvøya',
#    'routes': [109]}},
#  {'id': 110,
#   'date_created': '2023-04-29T11:34:05.329Z',
#   'date_updated': '2023-04-29T11:41:10.964Z',
#   'aspect': ['V', 'NV'],
#   'name': 'Fra Leira',
#   'dangers': None,
#   'comment': None,
#   'is_descent': False,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.592312, 62.117734],
#      [6.599264, 62.115446],
#      [6.601496, 62.11396],
#      [6.602783, 62.112435],
#      [6.603813, 62.11123],
#      [6.607161, 62.110628],
#      [6.609735, 62.109223],
#      [6.610937, 62.10854],
#      [6.615572, 62.108059],
#      [6.624498, 62.107737],
#      [6.628103, 62.108139],
#      [6.630721, 62.108822],
#      [6.632009, 62.110227],
#      [6.630549, 62.111331],
#      [6.628704, 62.112555],
#      [6.628532, 62.113318],
#      [6.628919, 62.115024],
#      [6.632009, 62.115486],
#      [6.634026, 62.115887],
#      [6.636386, 62.11667],
#      [6.638703, 62.117091],
#      [6.646042, 62.11671],
#      [6.648574, 62.116269],
#      [6.650634, 62.11653]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 61,
#    'name': 'Kårdalstindane',
#    'altitude': 1487,
#    'area': 'Rånahalvøya',
#    'routes': [93, 94, 110, 111]}},
#  {'id': 111,
#   'date_created': '2023-04-29T11:35:06.765Z',
#   'date_updated': '2023-04-29T11:41:23.732Z',
#   'aspect': ['S'],
#   'name': 'Sydflanken',
#   'dangers': None,
#   'comment': None,
#   'is_descent': True,
#   'geojson': {'type': 'Feature',
#    'properties': {},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[6.640205, 62.11675],
#      [6.639733, 62.115907],
#      [6.639948, 62.115104],
#      [6.640077, 62.114442],
#      [6.639562, 62.113057],
#      [6.639218, 62.111752],
#      [6.639218, 62.110668],
#      [6.638832, 62.109966],
#      [6.638832, 62.109524]]}},
#   'max_start_altitude': None,
#   'avalanche_start_zones': None,
#   'max_steepness': None,
#   'parking_location': None,
#   'exposure': None,
#   'difficulty': None,
#   'equipment': None,
#   'elevation': None,
#   'kast': None,
#   'dry_snow': False,
#   'is_couloir': False,
#   'peak_id': {'id': 61,
#    'name': 'Kårdalstindane',
#    'altitude': 1487,
#    'area': 'Rånahalvøya',
#    'routes': [93, 94, 110, 111]}}]

# %%
class Peak(BaseModel):
  id: int
  name: str
  altitude: Optional[int]
  area: str
  


class Route(BaseModel):
  id: int
  name: str
  max_start_altitude: Optional[int]
  avalanche_start_zones: Optional[list] = []
  kast: Optional[int]
  dangers: Optional[str]
  exposure: Optional[str]
  difficulty: Optional[str]
  comment: Optional[str]
  equipment: Optional[str]
  max_steepness: Optional[int]
  is_descent: Optional[bool]
  parking_location: Optional[str]
  geojson: dict 
  aspect: list 
  peak: Peak = Field(None, alias="peak_id")
  distance_in_km: Optional[int]
  elevation: Optional[int]
  dry_snow: bool = False
  is_couloir: bool = False

  @validator("*", pre=True)
  def none_to_default(cls, value, field):
    if (value == "" or value == None):
      return field.default
    return value

# %%
valid_routes = []
invalid_routes = []

for route in routes:
  try:
    r = Route(**route)
    valid_routes.append(r)
  except ValidationError as e:
    error_text = (
      f'{route }: \n'
      f'{e} \n'
      f'-------------'
    )
    print(error_text)

    invalid_routes.append(route)

# %%
print(f'Invalid routes: {len(invalid_routes)}')
print(f'Valid routes: {len(routes)}')
# Out:
# Invalid routes: 0
# Valid routes: 109

# %%
route_dicts = [route.dict() for route in valid_routes]
with open('routes.json', 'w') as file:
    file.write(json.dumps(route_dicts))
